# %%
s= "Rutika Vilas Zol"
#print(len(s))
char1 = s[3]
char2 = s[4]
char3 = s[5]
print(char1,char2,char3)
# Out:
# i k a

# %%
s = "Rutika Vilas Zol"
s1 = "Rutika Vilas Zol"

print(s1[0], s1[-1]) 
print(len(s1)) 

print(s1[0:6]) 
print(s1[7:12])
print(s1[13:16])
# Out:
# R l
# 16
# Rutika
# Vilas
# Zol
